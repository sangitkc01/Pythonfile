# %%
#web scrapping of real time billionaire

from bs4 import BeautifulSoup
import requests

url= BeautifulSoup('https://www.forbes.com/real-time-billionaires/#19f4f8823d78','html.parser')
soup= requests.get(url)
soup
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:431: MarkupResemblesLocatorWarning: "https://www.forbes.com/real-time-billionaires/#19f4f8823d78" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# <Response [200]>

# %%
soup.text
# Out:
# '<!doctype html><!--[if lt IE 7]>\t<html id="ng-app" class="no-js lt-ie10 lt-ie9 lt-ie8 lt-ie7" ng-app="forbesApp" lang="en"> <![endif]--><!--[if IE 7]>\t\t<html id="ng-app" class="no-js lt-ie10 lt-ie9 lt-ie8" ng-app="forbesApp" lang="en"> <![endif]--><!--[if IE 8]>\t\t<html id="ng-app"  class="no-js lt-ie10 lt-ie9" ng-app="forbesApp" lang="en"> <![endif]--><!--[if IE 9]>\t\t<html id="ng-app"  class="no-js lt-ie10" ng-app="forbesApp" lang="en"> <![endif]--><!--[if gt IE 9]<!--><html id="ng-app" class="no-js app-uninitialized" ng-app="forbesApp" lang="en"><!--<![endif]--><head ng-controller="MetaController"><meta charset="utf-8"><meta name="referrer" content="origin-when-cross-origin"><meta http-equiv="Content-Language" content="en_US"><title itemprop="headline">Real Time Billionaires</title><meta name="description" itemprop="description" content="Forbes\' Real-Time Billionaires rankings tracks the daily ups and downs of the world’s richest people. The wealth-tracking platform provide
# ...

# %%
soup=soup.text

# %%
obj=BeautifulSoup(soup,'lxml')
obj
# Out:
# <!DOCTYPE html>
# ...

# %%
Table=obj.find('thead',class_='ng-scope')
Table

# %%
Table.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9860/2033000153.py in <module>
# ----> 1 Table.text
#
# AttributeError: 'NoneType' object has no attribute 'text'
